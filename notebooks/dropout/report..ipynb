# %% [markdown]
# # Dropout Risk Report
#
# Generate the full dropout risk report and the actionable intervention report from the saved dropout model.

# %%
import sys
from pathlib import Path

base_dir = Path("../..").resolve()
sys.path.append(str(base_dir))

from src.predict import export_dropout_predictions, load_dropout_inputs, predict_dropout_students

# %%
feature_df, student_ids = load_dropout_inputs(base_dir)
report_df = predict_dropout_students(feature_df, student_ids=student_ids)
report_df.head()
# Out:
#    code_module  code_presentation  gender  region  highest_education  \
# 0            5                  3       0       5                  0
# 1            2                  3       0       3                  2
# 2            5                  3       1       3                  2
# 3            2                  3       0       5                  2
# 4            2                  3       0       6                  1
#
#    imd_band  age_band  num_of_prev_attempts  studied_credits  disability  \
# 0         0         0             -0.340229         2.440667           0
# 1         3         0             -0.340229         3.901543           0
# 2         2         0             -0.340229         3.901543           0
# 3         4         0             -0.340229         1.710230           0
# 4         0         0             -0.340229         1.710230           0
#
#    sum_click  date_registration  Student_ID  Risk_Probability_Value  \
# 0  -0.717923          -0.052552      648650                0.947931
# 1  -0.717923          -0.580366      675116                0.947148
# 2  -0.717923          -0.661568      640140                0.945845
# 3  -0.717923          -0.905175      489990                0.945460
# 4  -0.717923          -0.174355      647391                0.944580
#
#   Risk_Probability  ML_Prediction Prediction_Band  \
# 0            94.8%              1          band_1
# 1            94.7%              1          band_1
# 2            94.6%              1          band_1
# 3            94.5%              1          band_1
# 4            94.5%              1          band_1
#
#                        Primary_Risk_Factors         Intervention_Status
# 0  Low Online Engagement | High Course Load  ACTION REQUIRED: High Risk
# 1  Low Online Engagement | High Course Load  ACTION REQUIRED: High Risk
# 2  Low Online Engagement | High Course Load  ACTION REQUIRED: High Risk
# 3  Low Online Engagement | High Course Load  ACTION REQUIRED: High Risk
# 4  Low Online Engagement | High Course Load  ACTION REQUIRED: High Risk

# %%
report_path, actionable_path = export_dropout_predictions(base_dir)
print(f"Saved dropout report to: {report_path}")
print(f"Saved actionable dropout report to: {actionable_path}")
# Out:
# Saved dropout report to: /Users/admin/Documents/GitHub/testITprojc/data/processed/dropout/Student_risk_report.csv
# Saved actionable dropout report to: /Users/admin/Documents/GitHub/testITprojc/data/processed/dropout/actionable_weekly_risk_report.csv

# %%
report_columns = [
    "Student_ID",
    "Prediction_Band",
    "Risk_Probability",
    "Primary_Risk_Factors",
    "Intervention_Status",
]
report_df.loc[report_df["ML_Prediction"] == 1, report_columns].head(25)
# Out:
#     Student_ID Prediction_Band Risk_Probability  \
# 0       648650          band_1            94.8%
# 1       675116          band_1            94.7%
# 2       640140          band_1            94.6%
# 3       489990          band_1            94.5%
# 4       647391          band_1            94.5%
# 5       645906          band_1            94.3%
# 6       596245          band_1            94.2%
# 7       581716          band_1            94.2%
# 8       565707          band_1            94.2%
# 9       654732          band_1            94.2%
# 10      684886          band_1            94.2%
# 11      653051          band_1            94.1%
# 12      483343          band_1            94.1%
# 13      643269          band_1            94.1%
# 14      648354          band_1            94.1%
# 15      315633          band_1            94.1%
# 16      643021          band_1            94.1%
# 17      562758          band_1            94.1%
# 18      648820          band_1            94.0%
# 19      835603          band_1            94.0%
# 20      637939          band_1            94.0%
# 21      614623          band_1            94.0%
# 22      610831          band_1            94.0%
# 23      104215          band_1            93.9%
# 24      682359          band_1            93.8%
#
#                                  Primary_Risk_Factors  \
# 0            Low Online Engagement | High Course Load
# 1            Low Online Engagement | High Course Load
# 2            Low Online Engagement | High Course Load
# 3            Low Online Engagement | High Course Load
# 4            Low Online Engagement | High Course Load
# 5            Low Online Engagement | High Course Load
# 6            Low Online Engagement | High Course Load
# 7            Low Online Engagement | High Course Load
# 8            Low Online Engagement | High Course Load
# 9            Low Online Engagement | High Course Load
# 10           Low Online Engagement | High Course Load
# 11           Low Online Engagement | High Course Load
# 12           Low Online Engagement | High Course Load
# 13           Low Online Engagement | High Course Load
# 14  Low Online Engagement | Late Registration | Hi...
# 15           Low Online Engagement | High Course Load
# 16           Low Online Engagement | High Course Load
# 17           Low Online Engagement | High Course Load
# 18           Low Online Engagement | High Course Load
# 19           Low Online Engagement | High Course Load
# 20           Low Online Engagement | High Course Load
# 21           Low Online Engagement | High Course Load
# 22           Low Online Engagement | High Course Load
# 23           Low Online Engagement | High Course Load
# 24           Low Online Engagement | High Course Load
#
#            Intervention_Status
# 0   ACTION REQUIRED: High Risk
# 1   ACTION REQUIRED: High Risk
# 2   ACTION REQUIRED: High Risk
# 3   ACTION REQUIRED: High Risk
# 4   ACTION REQUIRED: High Risk
# 5   ACTION REQUIRED: High Risk
# 6   ACTION REQUIRED: High Risk
# 7   ACTION REQUIRED: High Risk
# 8   ACTION REQUIRED: High Risk
# 9   ACTION REQUIRED: High Risk
# 10  ACTION REQUIRED: High Risk
# 11  ACTION REQUIRED: High Risk
# 12  ACTION REQUIRED: High Risk
# 13  ACTION REQUIRED: High Risk
# 14  ACTION REQUIRED: High Risk
# 15  ACTION REQUIRED: High Risk
# 16  ACTION REQUIRED: High Risk
# 17  ACTION REQUIRED: High Risk
# 18  ACTION REQUIRED: High Risk
# 19  ACTION REQUIRED: High Risk
# 20  ACTION REQUIRED: High Risk
# 21  ACTION REQUIRED: High Risk
# 22  ACTION REQUIRED: High Risk
# 23  ACTION REQUIRED: High Risk
# 24  ACTION REQUIRED: High Risk
